# %%
# パーセプトロンの数
N = 3  # 入力層(説明変数)の数
K = 20  # 隠れ層の数
M = 2  # 出力層(目的変数)の数

# モデルの定義(3層ニューラルネットワーク)
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(16, 3)))
model.add(tf.keras.layers.Dense(K, activation='relu'))
model.add(tf.keras.layers.Dense(M, activation='softmax'))
# model.add(Dropout(0.5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9n/jgw8km7j70q_t2ch23y32fl80000gn/T/ipykernel_91653/1969147509.py in <module>
#       5
#       6 # モデルの定義(3層ニューラルネットワーク)
# ----> 7 model = tf.keras.Sequential()
#       8 model.add(tf.keras.Input(shape=(16, 3)))
#       9 model.add(tf.keras.layers.Dense(K, activation='relu'))
#
# NameError: name 'tf' is not defined

# %%
# 最適化の手法や損失関数などを定義(compile)
model.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop',
    metrics=['accuracy']
)

# モデルの概要表示
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16, 20)            80
#
#  dense_5 (Dense)             (None, 16, 2)             42
#
# =================================================================
# Total params: 122
# Trainable params: 122
# Non-trainable params: 0
# _________________________________________________________________

# %%
# トレーニングの実行(fit)
# 訓練データと教師データ
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience=10, verbose=0) 

model.fit(x_train, y_train, # トレーニングデータ
          None, # 
          256, # トレーニングの回数
          validation_data=(x_eval, y_eval), # 評価用データ
          callbacks=[early_stopping] # モデルの過学習を抑制する(損失関数の改善が、「patience」で指定したエポック数の間にないと訓練を終了)
         )
# Out:
# Epoch 1/256
# 1/1 [==============================] - 0s 101ms/step - loss: 0.3923 - accuracy: 0.9286 - val_loss: 0.4644 - val_accuracy: 0.9107
# Epoch 2/256
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3923 - accuracy: 0.9286 - val_loss: 0.4644 - val_accuracy: 0.9107
# Epoch 3/256
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3923 - accuracy: 0.9286 - val_loss: 0.4646 - val_accuracy: 0.9107
# Epoch 4/256
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3922 - accuracy: 0.9286 - val_loss: 0.4644 - val_accuracy: 0.9107
# Epoch 5/256
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3922 - accuracy: 0.9286 - val_loss: 0.4647 - val_accuracy: 0.9107
# Epoch 6/256
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3922 - accuracy: 0.9286 - val_loss: 0.4646 - val_accuracy: 0.9107
# Epoch 7/256
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3921 - accuracy: 0.9286 - val_loss: 0.4650 - val_accuracy: 0.9107
# Epoch 8/256
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3921 - accuracy: 0.9286 - val_loss: 0.4647 - val_accuracy: 0.9107
# Epoch 9/256
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3921 - accuracy: 0.9286 - val_loss: 0.4649 - val_accuracy: 0.9107
# Epoch 10/256
# 1/1 [==============================] - 0s 43ms/step - loss: 0.3921 - accuracy: 0.9286 - val_loss: 0.4649 - val_accuracy: 0.9107
# Epoch 11/256
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3920 - accuracy: 0.9286 - val_loss: 0.4651 - val_accuracy: 0.9107
# Epoch 12/256
# 1/1 [==============================] - 0s 41ms/step - loss: 0.3920 - accuracy: 0.9286 - val_loss: 0.4651 - val_accuracy: 0.9107

# %%
sources = model.evaluate(format_training_data, format_training_answer_data)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4182 - accuracy: 0.9804

# %%
# modelの評価
# テストデータで予測
y_pred = model.predict(x_test)
y_pred_max = np.argmax(y_pred, axis=1)
print(y_pred)

# テストデータの予測 (予測クラス(0 or 1)を返す)
# 説明変数を与えて、0.5以上であれば１とみなす。それ以下は０とみなす（説明変数の集合→学習→0or1→flagと比較)
y_pred = np.where(y_pred_prob < 0.5, 0, 1) # 0.5より小さい場合0 ,そうでない場合1を返す
# Out:
# 1/1 [==============================] - 0s 33ms/step
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas


# パーセプトロンの数
N = 3  # 入力層の数
K = 20  # 隠れ層の数
M = 2  # 出力層の数

# データセットの読み込み
data = pandas.read_csv("race_data.csv")

# カラム指定の上列抽出
training_data = data.loc[:, ["race_id", "Nhorse_age", "Nhorse_weight", "Nweight_change", "isThird", "isSecond"]]
converted_np_array = training_data.values


# データの正規化
# mapにばらして、race_idごとに分けていく
# つまり
# mp[race_id_no1] = [
#   [1,2,3,4,5,6],
#   [1,2,3,4,5,6],
# ]
# {202203020101:[[0.3, -3, -0.3],[0.2, 0.3, 0.3]], 202203020102:[[0.2,1,1]]}
# みたいなデータが出来る
mp = {}
mp_answer = {}
for r in converted_np_array:
    if r[0] in mp:
        mp[r[0]].append(r[1:4].tolist())
        mp_answer[r[0]].append(r[4:6].tolist())
    else:
        mp[r[0]] = []
        mp_answer[r[0]] = []
        mp[r[0]].append(r[1:4].tolist())
        mp_answer[r[0]].append(r[4:6].tolist())

# データの正規化
tmp_data = []
tmp_answer = []
for key in mp.keys():
    tmp_data.append(mp[key])
    tmp_answer.append(mp_answer[key])
# ちょい怠いので一旦16頭建てのレース以外排除する
#  [[[[0.3, -3, -0.3],[0.2, 0.3, 0.3]]]]
training_data = []
answer_data = []
for index in range(0, len(tmp_data)):
    if len(tmp_data[index]) == 16:
        training_data.append(tmp_data[index])
        answer_data.append(tmp_answer[index])

# Todo 3割をテスト。７割を学習(test_dataとtraining_dataを3,7の割合にする)
from sklearn.model_selection import train_test_split
# 学習データとテストデータに分ける
x_train, x_test, y_train, y_test = train_test_split(training_data, answer_data, random_state=0, test_size=0.3)

# 学習データを、学習用と検証用に分ける
x_train, x_eval, y_train, y_eval = train_test_split(x_train, y_train,
                                                    test_size=0.2,
                                                    random_state=1,
                                                    # stratify=y_train
                                                    )

# モデルの定義(3層ニューラルネットワーク)
model = tf.keras.Sequential()
model.add(tf.keras.Input(shape=(16, 3)))
model.add(tf.keras.layers.Dense(K, activation='relu'))
model.add(tf.keras.layers.Dense(M, activation='softmax'))
# Out:
# 2022-11-15 23:49:07.703952: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-15 23:49:34.435965: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas

# データセットの読み込み
data = pandas.read_csv("race_data.csv")

# カラム指定の上列抽出
specific_data = data.loc[:, ["race_id", "Nhorse_age", "Nhorse_weight", "Nweight_change", "isThird", "isSecond"]]
converted_np_array = specific_data.values
# Out:
# 2022-11-16 00:32:26.513320: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 3771    0
# 3772    0
# 3773    0
# 3774    0
# 3775    0
# Name: isThird, Length: 3776, dtype: int64

# %%
# データの正規化
# mapにばらして、race_idごとに分けていく
# つまり
# mp[race_id_no1] = [
#   [1,2,3,4,5,6],
#   [1,2,3,4,5,6],
# ]
# {202203020101:[[0.3, -3, -0.3],[0.2, 0.3, 0.3]], 202203020102:[[0.2,1,1]]}
# みたいなデータが出来る
x_mp = {} # 説明変数
y_mp = {} # 目的変数
for r in converted_np_array:
    if r[0] in x_mp:
        x_mp[r[0]].append(r[1:4].tolist())
        y_mp[r[0]].append(r[4:6].tolist())
    else:
        x_mp[r[0]] = []
        y_mp[r[0]] = []
        x_mp[r[0]].append(r[1:4].tolist())
        y_mp[r[0]].append(r[4:6].tolist())

# %%
# データの正規化
x_tmp = []
y_tmp = []
for key in x_mp.keys():
    x_tmp.append(x_mp[key])
    y_tmp.append(y_mp[key])
# ちょい怠いので一旦16頭建てのレース以外排除する
#  [[[[0.3, -3, -0.3],[0.2, 0.3, 0.3]]]]

x_data = [] # 説明変数
y_data = [] # 目的変数
for index in range(0, len(x_tmp)):
    if len(x_tmp[index]) == 16:
        x_data.append(x_tmp[index])
        y_data.append(y_tmp[index])

# %%
from sklearn.model_selection import train_test_split
# 学習データとテストデータに分ける
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data
6255432421712243, -0.4555734516094202], [-1.336198002249133, -2.1546489452564392, 0.8697311348907113], [-1.336198002249133, -1.0425720702853738, 0.8697311348907113], [-0.3181423814878888, 0.6255432421712243, -0.1242473049843873], [1.7179688600346, 0.6255432421712243, -1.118225744859486], [0.6999132392733555, -0.4865336327998411, 1.201057281515744], [0.6999132392733555, 0.6255432421712243, 0.2070788416406455], [-0.3181423814878888, 0.6255432421712243, -0.4555734516094202], [-1.336198002249133, -2.1546489452564392, 0.5384049882656784], [1.7179688600346, 0.6255432421712243, -0.4555734516094202], [0.6999132392733555, 0.6255432421712243, 1.532383428140777], [-0.3181423814878888, 0.6255432421712243, -0.4555734516094202], [-0.3181423814878888, 0.6255432421712243, -1.118225744859486], [0.6999132392733555, 0.6255432421712243, -0.4555734516094202]], [[0.0, -1.410028251146314, 0.616847170218349], [0.0, -0.6320816298242097, 2.496762355645698], [0.0, -2.187974872468418, -1.0280786170305816], [0.0, 0.9238116128199988, -1.0280786170305816], [0.0, 0.9238116128199988, 0.616847170218349], [0.0, 0.9238116128199988, 0.616847170218349], [0.0, -0.6320816298242097, -0.5580998206737443], [0.0, -0.6320816298242097, -0.3231104224953257], [0.0, 0.9238116128199988, 0.3818577720399303], [0.0, 0.9238116128199988, -0. ...

# %%
conda install -c conda-forge lightgbm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/endo_ryo/opt/anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.9.0               |   py39h6e9494a_2         962 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         962 KB
#
# The following packages will be UPDATED:
#
#   conda                               22.9.0-py39h6e9494a_1 --> 22.9.0-py39h6e9494a_2 None
#
#
#
# Downloading and Extracting Packages
# conda-22.9.0         | 962 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.1-py3-none-macosx_10_15_x86_64.macosx_11_0_x86_64.macosx_12_0_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 272 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/endo_ryo/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.20.3)
# Requirement already satisfied: scipy in /Users/endo_ryo/opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb


# 2次元に変換する
converted_x_train = sum(x_train, [])
converted_y_train = sum(y_train, [])
converted_x_eval = sum(x_eval, [])
converted_y_eval = sum(y_eval, [])
converted_x_test = sum(x_test, [])
converted_y_test = sum(y_test, [])


# データを格納する
# 学習用
xgb_train = xgb.DMatrix(converted_x_train, label=converted_y_train)

# 検証用
xgb_eval = xgb.DMatrix(converted_x_eval, label=converted_y_eval)

# テスト用
xgb_test = xgb.DMatrix(converted_x_test, label=converted_y_test)

# %%
# クラスの比率
r_isThird, r_not_isThird = len(specific_data["isThird"] == 1), len(specific_data["isThird"] == 0)
r_all = r_isThird + r_not_isThird
print('3着以内 の割合 :',r_isThird/r_all) 
print('3着より下 の割合 :',r_not_isThird/r_all)
print(r_all)
# Out:
# 3着以内 の割合 : 0.5
# 3着より下 の割合 : 0.5
# 7552

# %%
# モデルの学習
import lightgbm as lgb #LightGBM
model = lgb.LGBMClassifier() # モデルのインスタンスの作成

xgb_params = {
    'objective': 'binary:logistic',  # 2値分類問題
    'learning_rate': 0.1,            # 学習率
    'eval_metric': 'mlogloss'       # 学習用の指標
}

# 2次元に変える
# 説明変数→目的変数に変換(まずは説明変数から0or1を予測してあげる)

#model.fit(converted_x_train[0][0], converted_y_train[0][0]) # モデルの学習

# %%
evals = [(xgb_train, 'train'), (xgb_eval, 'eval')] # 学習に用いる検証用データ
evaluation_results = {}                            # 学習の経過を保存する箱
bst = xgb.train(xgb_params,
                    xgb_train,
                    num_boost_round=100,  # 学習ラウンド数は適当
                    )

# %%
y_pred_proba = bst.predict(xgb_test)

# %%
y_pred = np.where(y_pred_proba > 0.5, 1, 0)

# %%
# Accuracy の計算
from sklearn.metrics import accuracy_score
acc = accuracy_score(converted_y_test, y_pred)
print(acc)
# Out:
# 0.74609375

# %%
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import tensorflow as tf
import numpy as np
import pandas
import xgboost as xgb
import lightgbm as lgb

# データセットの読み込み
data = pandas.read_csv("race_data.csv")

# カラム指定の上列抽出
specific_data = data.loc[:, ["race_id", "Nhorse_age", "Nhorse_weight", "Nweight_change", "isThird", "isSecond"]]
converted_np_array = specific_data.values

# データの正規化
# mapにばらして、race_idごとに分けていく
# つまり
# mp[race_id_no1] = [
#   [1,2,3,4,5,6],
#   [1,2,3,4,5,6],
# ]
# {202203020101:[[0.3, -3, -0.3],[0.2, 0.3, 0.3]], 202203020102:[[0.2,1,1]]}
# みたいなデータが出来る
x_mp = {} # 説明変数
y_mp = {} # 目的変数
for r in converted_np_array:
    if r[0] in x_mp:
        x_mp[r[0]].append(r[1:4].tolist())
        y_mp[r[0]].append(r[4:6].tolist())
    else:
        x_mp[r[0]] = []
        y_mp[r[0]] = []
        x_mp[r[0]].append(r[1:4].tolist())
        y_mp[r[0]].append(r[4:6].tolist())

# データの正規化
x_tmp = []
y_tmp = []
for key in x_mp.keys():
    x_tmp.append(x_mp[key])
    y_tmp.append(y_mp[key])
# ちょい怠いので一旦16頭建てのレース以外排除する
#  [[[[0.3, -3, -0.3],[0.2, 0.3, 0.3]]]]

x_data = [] # 説明変数
y_data = [] # 目的変数
for index in range(0, len(x_tmp)):
    if len(x_tmp[index]) == 16:
        x_data.append(x_tmp[index])
        y_data.append(y_tmp[index])


# 学習データとテストデータに分ける
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, random_state=0, test_size=0.3)

# 学習データを、学習用と検証用に分ける
x_train, x_eval, y_train, y_eval = train_test_split(x_train, y_train,test_size=0.2,random_state=1,
                                                    # stratify=y_train
                                                  )


# 2次元に変換する
converted_x_train = sum(x_train, [])
converted_y_train = sum(y_train, [])
converted_x_eval = sum(x_eval, [])
converted_y_eval = sum(y_eval, [])
converted_x_test = sum(x_test, [])
converted_y_test = sum(y_test, [])


# データを格納する
# 学習用
xgb_train = xgb.DMatrix(converted_x_train, label=converted_y_train)

# 検証用
xgb_eval = xgb.DMatrix(converted_x_eval, label=converted_y_eval)

# テスト用
xgb_test = xgb.DMatrix(converted_x_test, label=converted_y_test)

# クラスの比率
r_isThird, r_not_isThird = len(specific_data["isThird"] == 1), len(specific_data["isThird"] == 0)
r_all = r_isThird + r_not_isThird
print('3着以内 の割合 :',r_isThird/r_all) 
print('3着より下 の割合 :',r_not_isThird/r_all)
print(r_all)


# モデルの学習

model = lgb.LGBMClassifier() # モデルのインスタンスの作成
xgb_params = {
    'objective': 'binary:logistic',  # 2値分類問題
    'learning_rate': 0.1,            # 学習率
    'eval_metric': 'mlogloss'       # 学習用の指標
}
bst = xgb.train(xgb_params,
                    xgb_train,
                    num_boost_round=100,  # 学習ラウンド数は適当
                    )

y_pred_proba = bst.predict(xgb_test)
y_pred = np.where(y_pred_proba > 0.5, 1, 0)

acc = accuracy_score(converted_y_test, y_pred)
print(acc)
# Out:
# 3着以内 の割合 : 0.5
# 3着より下 の割合 : 0.5
# 7552
# 0.74609375
